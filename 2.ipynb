# %%
a = 0
b = 2

'df_{}_{}'.format(b,a)
# Out:
# 'df_2_0'

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Scaling과 Normalization

# %%
import pandas as pd
import numpy as np

from scipy import stats

from mlxtend.preprocessing import minmax_scaling

import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)

# %%
# 지수 분포에서 무작위로 추출한 1000개의 데이터 포인트 생성
original_data = np.random.exponential(size=1000)

# mix-max 0과 1 사이의 데이터 스케일
scaled_data = minmax_scaling(original_data, columns=[0])

# 비교하기 위해 둘 모두를 그래프로 그림
fig, ax = plt.subplots(1,2)
sns.distplot(original_data, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("Scaled data")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Scaled data')

# %%
sns.distplot(np.log(original_data))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # 결측치

# %%
import pandas as pd
import numpy as np

nfl_data = pd.read_csv("/content/drive/MyDrive/21_ls/data/NFL Play by Play 2009-2017 (v4).csv")

np.random.seed(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (25,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# 열당 누락된(null 값의) 데이터의 수
missing_values_count = nfl_data.isnull().sum()

# 상위 10개의 열에서 누락된 데이터의 수 보기
missing_values_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %%
# 총 결측값의 수
total_cells = np.product(nfl_data.shape)
total_missing = missing_values_count.sum()

# 누락된 데이터 비율
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 24.87214126835169

# %%
nfl_data.dropna()
# Out:
# Empty DataFrame
# Columns: [Date, GameID, Drive, qtr, down, time, TimeUnder, TimeSecs, PlayTimeDiff, SideofField, yrdln, yrdline100, ydstogo, ydsnet, GoalToGo, FirstDown, posteam, DefensiveTeam, desc, PlayAttempted, Yards.Gained, sp, Touchdown, ExPointResult, TwoPointConv, DefTwoPoint, Safety, Onsidekick, PuntResult, PlayType, Passer, Passer_ID, PassAttempt, PassOutcome, PassLength, AirYards, YardsAfterCatch, QBHit, PassLocation, InterceptionThrown, Interceptor, Rusher, Rusher_ID, RushAttempt, RunLocation, RunGap, Receiver, Receiver_ID, Reception, ReturnResult, Returner, BlockingPlayer, Tackler1, Tackler2, FieldGoalResult, FieldGoalDistance, Fumble, RecFumbTeam, RecFumbPlayer, Sack, Challenge.Replay, ChalReplayResult, Accepted.Penalty, PenalizedTeam, PenaltyType, PenalizedPlayer, Penalty.Yards, PosTeamScore, DefTeamScore, ScoreDiff, AbsScoreDiff, HomeTeam, AwayTeam, Timeout_Indicator, Timeout_Team, posteam_timeouts_pre, HomeTimeouts_Remaining_Pre, AwayTimeouts_Remaining_Pre, HomeTimeouts_Remaining_Post, AwayTimeouts_Remaining_Post, No_Score_Prob, Opp_Field_Goal_Prob, Opp_Safety_Prob, Opp_Touchdown_Prob, Field_Goal_Prob, Safety_Prob, Touchdown_Prob, ExPoint_Prob, TwoPoint_Prob, ExpPts, EPA, airEPA, yacEPA, Home_WP_pre, Away_WP_pre, Home_WP_post, Away_WP_post, Win_Prob, WPA, airWPA, ...]
# Index: []
#
# [0 rows x 102 columns]

# %%
nfl_data.dropna(axis=1)
# Out:
#               Date      GameID  Drive  ...  ExPoint_Prob  TwoPoint_Prob  Season
# 0       2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 1       2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 2       2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 3       2009-09-10  2009091000      1  ...           0.0            0.0    2009
# 4       2009-09-10  2009091000      1  ...           0.0            0.0    2009
# ...            ...         ...    ...  ...           ...            ...     ...
# 407683  2017-12-31  2017123101     29  ...           0.0            0.0    2017
# 407684  2017-12-31  2017123101     29  ...           0.0            0.0    2017
# 407685  2017-12-31  2017123101     29  ...           0.0            0.0    2017
# 407686  2017-12-31  2017123101     30  ...           0.0            0.0    2017
# 407687  2017-12-31  2017123101     30  ...           0.0            0.0    2017
#
# [407688 rows x 41 columns]

# %%
# 보기 쉽게 NFL 데이터셋에서 EPA 에서 Season 까지의 컬럼만을 추출
subset_nfl_data = nfl_data.loc[:, 'EPA':'Season'].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  ...    airWPA    yacWPA  Season
# 0  2.014474       NaN       NaN  ...       NaN       NaN    2009
# 1  0.077907 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 2 -1.402760       NaN       NaN  ...       NaN       NaN    2009
# 3 -1.712583  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 4  2.097796       NaN       NaN  ...       NaN       NaN    2009
#
# [5 rows x 12 columns]

# %%
# 모든 Na값을 0으로 채우기
subset_nfl_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  ...    airWPA    yacWPA  Season
# 0  2.014474  0.000000  0.000000  ...  0.000000  0.000000    2009
# 1  0.077907 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 2 -1.402760  0.000000  0.000000  ...  0.000000  0.000000    2009
# 3 -1.712583  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 4  2.097796  0.000000  0.000000  ...  0.000000  0.000000    2009
#
# [5 rows x 12 columns]

# %%
# 동일한 열에서 모든 NA 값을 다음에 오는 값으로 대체합니다.
# 나머지 na를 모두 0으로 바꿉니다.
subset_nfl_data.fillna(method='bfill', axis=0).fillna(0)
# Out:
#         EPA    airEPA    yacEPA  ...    airWPA    yacWPA  Season
# 0  2.014474 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 1  0.077907 -1.068169  1.146076  ... -0.032244  0.036899    2009
# 2 -1.402760  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 3 -1.712583  3.318841 -5.031425  ...  0.106663 -0.156239    2009
# 4  2.097796  0.000000  0.000000  ...  0.000000  0.000000    2009
#
# [5 rows x 12 columns]

# %% [markdown]
# # 날짜 및 시간변수 처리

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

landslides = pd.read_csv("/content/drive/MyDrive/21_ls/data/catalog.csv")

np.random.seed(0)

# %%
landslides.head()
# Out:
#    id  ...                                        source_link
# 0  34  ...      http://www.nbc4.com/news/11186871/detail.html
# 1  42  ...  http://www.cantonrep.com/index.php?ID=345054&C...
# 2  56  ...  https://web.archive.org/web/20080423132842/htt...
# 3  59  ...  http://www.hebdos.net/lsc/edition162007/articl...
# 4  61  ...                                                NaN
#
# [5 rows x 23 columns]

# %%
print(landslides['date'].head())
# Out:
# 0     3/2/07
# 1    3/22/07
# 2     4/6/07
# 3    4/14/07
# 4    4/15/07
# Name: date, dtype: object

# %%
landslides['date'].dtype
# Out:
# dtype('O')

# %%
landslides['date_parsed'] = pd.to_datetime(landslides['date'], format="%m/%d/%y")

# %%
landslides['date_parsed'].head()
# Out:
# 0   2007-03-02
# 1   2007-03-22
# 2   2007-04-06
# 3   2007-04-14
# 4   2007-04-15
# Name: date_parsed, dtype: datetime64[ns]

# %%
day_of_month_landslides = landslides['date_parsed'].dt.day
day_of_month_landslides.head()
# Out:
# 0     2.0
# 1    22.0
# 2     6.0
# 3    14.0
# 4    15.0
# Name: date_parsed, dtype: float64

# %% [markdown]
# # Pandas 활용

# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
wine_reviews = pd.read_csv("/content/drive/MyDrive/21_ls/data/winemag-data-130k-v2.csv")

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country  ...         variety               winery
# 0           0     Italy  ...     White Blend              Nicosia
# 1           1  Portugal  ...  Portuguese Red  Quinta dos Avidagos
# 2           2        US  ...      Pinot Gris            Rainstorm
# 3           3        US  ...        Riesling           St. Julian
# 4           4        US  ...      Pinot Noir         Sweet Cheeks
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Native accessors

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# ## Indexing in pandas

# %%
wine_reviews.iloc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# winery                                                             Nicosia
# Name: 0, dtype: object

# %%
wine_reviews.iloc[:, 0]
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 129966    129966
# 129967    129967
# 129968    129968
# 129969    129969
# 129970    129970
# Name: Unnamed: 0, Length: 129971, dtype: int64

# %%
wine_reviews.iloc[:3, 0]
# Out:
# 0    0
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64

# %%
wine_reviews.iloc[1:3, 0]
# Out:
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64

# %%
wine_reviews.iloc[-5:]
# Out:
#         Unnamed: 0  ...                                    winery
# 129966      129966  ...  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967      129967  ...                                  Citation
# 129968      129968  ...                           Domaine Gresser
# 129969      129969  ...                      Domaine Marcel Deiss
# 129970      129970  ...                          Domaine Schoffit
#
# [5 rows x 14 columns]

# %%
wine_reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
wine_reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#                taster_name taster_twitter_handle  points
# 0            Kerin O’Keefe          @kerinokeefe      87
# 1               Roger Voss            @vossroger      87
# 2             Paul Gregutt           @paulgwine       87
# 3       Alexander Peartree                   NaN      87
# 4             Paul Gregutt           @paulgwine       87
# ...                    ...                   ...     ...
# 129966  Anna Lee C. Iijima                   NaN      90
# 129967        Paul Gregutt           @paulgwine       90
# 129968          Roger Voss            @vossroger      90
# 129969          Roger Voss            @vossroger      90
# 129970          Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %% [markdown]
# ## Manipulating the index

# %%
wine_reviews.set_index("title")
# Out:
#                                                     Unnamed: 0  ...                                    winery
# title                                                           ...
# Nicosia 2013 Vulkà Bianco  (Etna)                            0  ...                                   Nicosia
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                1  ...                       Quinta dos Avidagos
# Rainstorm 2013 Pinot Gris (Willamette Valley)                2  ...                                 Rainstorm
# St. Julian 2013 Reserve Late Harvest Riesling (...           3  ...                                St. Julian
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           4  ...                              Sweet Cheeks
# ...                                                        ...  ...                                       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...      129966  ...  Dr. H. Thanisch (Erben Müller-Burggraef)
# Citation 2004 Pinot Noir (Oregon)                       129967  ...                                  Citation
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)      129968  ...                           Domaine Gresser
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)           129969  ...                      Domaine Marcel Deiss
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...      129970  ...                          Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# ## Conditional selection

# %%
wine_reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country == 'Italy']
# Out:
#         Unnamed: 0 country  ...            variety                           winery
# 0                0   Italy  ...        White Blend                          Nicosia
# 6                6   Italy  ...           Frappato                  Terre di Giurfo
# 13              13   Italy  ...  Nerello Mascalese              Masseria Setteporte
# 22              22   Italy  ...        White Blend               Baglio di Pianetto
# 24              24   Italy  ...       Nero d'Avola                        Canicattì
# ...            ...     ...  ...                ...                              ...
# 129929      129929   Italy  ...           Prosecco             Col Vetoraz Spumanti
# 129943      129943   Italy  ...          Red Blend  Baglio del Cristo di Campobello
# 129947      129947   Italy  ...          Red Blend         Feudo Principi di Butera
# 129961      129961   Italy  ...           Frappato                              COS
# 129962      129962   Italy  ...       Nero d'Avola                         Cusumano
#
# [19540 rows x 14 columns]

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.points >= 90)]
# Out:
#         Unnamed: 0 country  ...       variety                           winery
# 120            120   Italy  ...      Nebbiolo                          Ceretto
# 130            130   Italy  ...      Nebbiolo                          Ceretto
# 133            133   Italy  ...      Nebbiolo             Poderi Luigi Einaudi
# 135            135   Italy  ...      Nebbiolo                  Giacomo Ascheri
# 140            140   Italy  ...       Barbera                     Poderi Colla
# ...            ...     ...  ...           ...                              ...
# 129929      129929   Italy  ...      Prosecco             Col Vetoraz Spumanti
# 129943      129943   Italy  ...     Red Blend  Baglio del Cristo di Campobello
# 129947      129947   Italy  ...     Red Blend         Feudo Principi di Butera
# 129961      129961   Italy  ...      Frappato                              COS
# 129962      129962   Italy  ...  Nero d'Avola                         Cusumano
#
# [6648 rows x 14 columns]

# %%
wine_reviews.loc[wine_reviews.country.isin(['Italy', 'France'])]
# Out:
#         Unnamed: 0 country  ...         variety                   winery
# 0                0   Italy  ...     White Blend                  Nicosia
# 6                6   Italy  ...        Frappato          Terre di Giurfo
# 7                7  France  ...  Gewürztraminer                 Trimbach
# 9                9  France  ...      Pinot Gris       Jean-Baptiste Adam
# 11              11  France  ...  Gewürztraminer               Leon Beyer
# ...            ...     ...  ...             ...                      ...
# 129964      129964  France  ...  Gewürztraminer          Domaine Ehrhart
# 129965      129965  France  ...      Pinot Gris  Domaine Rieflé-Landmann
# 129968      129968  France  ...  Gewürztraminer          Domaine Gresser
# 129969      129969  France  ...      Pinot Gris     Domaine Marcel Deiss
# 129970      129970  France  ...  Gewürztraminer         Domaine Schoffit
#
# [41633 rows x 14 columns]

# %%
wine_reviews.loc[wine_reviews.price.notnull()]
# Out:
#         Unnamed: 0  ...                                    winery
# 1                1  ...                       Quinta dos Avidagos
# 2                2  ...                                 Rainstorm
# 3                3  ...                                St. Julian
# 4                4  ...                              Sweet Cheeks
# 5                5  ...                                    Tandem
# ...            ...  ...                                       ...
# 129966      129966  ...  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967      129967  ...                                  Citation
# 129968      129968  ...                           Domaine Gresser
# 129969      129969  ...                      Domaine Marcel Deiss
# 129970      129970  ...                          Domaine Schoffit
#
# [120975 rows x 14 columns]

# %% [markdown]
# ## Assigning data

# %%
wine_reviews['critic'] = 'everyone'
wine_reviews['critic']
# Out:
# 0         everyone
# 1         everyone
# 2         everyone
# 3         everyone
# 4         everyone
#             ...
# 129966    everyone
# 129967    everyone
# 129968    everyone
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %% [markdown]
# ## Summary functions

# %%
wine_reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
wine_reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
wine_reviews.points.mean()
# Out:
# 88.44713820775404

# %%
wine_reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
wine_reviews.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %% [markdown]
# ## Maps

# %%
review_points_mean = wine_reviews.points.mean()
wine_reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

wine_reviews.apply(remean_points, axis='columns')
# Out:
#         Unnamed: 0  ...    critic
# 0                0  ...  everyone
# 1                1  ...  everyone
# 2                2  ...  everyone
# 3                3  ...  everyone
# 4                4  ...  everyone
# ...            ...  ...       ...
# 129966      129966  ...  everyone
# 129967      129967  ...  everyone
# 129968      129968  ...  everyone
# 129969      129969  ...  everyone
# 129970      129970  ...  everyone
#
# [129971 rows x 15 columns]

# %%
wine_reviews.head(1)
# Out:
#    Unnamed: 0 country  ...   winery    critic
# 0           0   Italy  ...  Nicosia  everyone
#
# [1 rows x 15 columns]

# %%
review_points_mean = wine_reviews.points.mean()
wine_reviews.points - review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
wine_reviews.country + " - " + wine_reviews.region_1
# Out:
# 0                     Italy - Etna
# 1                              NaN
# 2           US - Willamette Valley
# 3         US - Lake Michigan Shore
# 4           US - Willamette Valley
#                     ...
# 129966                         NaN
# 129967                 US - Oregon
# 129968             France - Alsace
# 129969             France - Alsace
# 129970             France - Alsace
# Length: 129971, dtype: object

# %% [markdown]
# ## Groupwise analysis

# %%
wine_reviews.groupby('points').points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
wine_reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
wine_reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
wine_reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                             Unnamed: 0  ...    critic
# country   province                      ...
# Argentina Mendoza Province       82754  ...  everyone
#           Other                  78303  ...  everyone
# Armenia   Armenia                66146  ...  everyone
# Australia Australia Other        37882  ...  everyone
#           New South Wales        85337  ...  everyone
# ...                                ...  ...       ...
# Uruguay   Juanico                 9133  ...  everyone
#           Montevideo             15750  ...  everyone
#           Progreso               93103  ...  everyone
#           San Jose               39898  ...  everyone
#           Uruguay                39361  ...  everyone
#
# [425 rows x 15 columns]

# %%
wine_reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#                           len   min     max
# country
# Argentina                3800   4.0   230.0
# Armenia                     2  14.0    15.0
# Australia                2329   5.0   850.0
# Austria                  3345   7.0  1100.0
# Bosnia and Herzegovina      2  12.0    13.0
# Brazil                     52  10.0    60.0
# Bulgaria                  141   8.0   100.0
# Canada                    257  12.0   120.0
# Chile                    4472   5.0   400.0
# China                       1  18.0    18.0
# Croatia                    73  12.0    65.0
# Cyprus                     11  11.0    21.0
# Czech Republic             12  15.0    45.0
# Egypt                       1   NaN     NaN
# England                    74  25.0    95.0
# France                  22093   5.0  3300.0
# Georgia                    86   9.0    40.0
# Germany                  2165   5.0   775.0
# Greece                    466   8.0    79.0
# Hungary                   146  10.0   764.0
# India                       9  10.0    20.0
# Israel                    505   8.0   150.0
# Italy                   19540   5.0   900.0
# Lebanon                    35  13.0    75.0
# Luxembourg                  6  16.0    30.0
# Macedonia                  12  15.0    20.0
# Mexico                     70   8.0   108.0
# Moldova                    59   8.0    42.0
# Morocco                    28  14.0    40.0
# New Zealand              1419   7.0   130.0
# Peru                       16  10.0    68.0
# Portugal                 5691   5.0  1000.0
# Romania                   120   4.0   320.0
# Serbia                     12  15.0    42.0
# Slovakia                    1  16.0    16.0
# Slovenia                   87   7.0    90.0
# South Africa             1401   5.0   330.0
# Spain                    6645   4.0   770.0
# Switzerland                 7  21.0   160.0
# Turkey                     90  14.0   120.0
# US                      54504   4.0  2013.0
# Ukraine                    14   6.0    13.0
# Uruguay                   109  10.0   130.0

# %% [markdown]
# ## Multi-indexes

# %%
countries_reviewed = wine_reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# Armenia   Armenia              2
# Australia Australia Other    245
#           New South Wales     85
# ...                          ...
# Uruguay   Juanico             12
#           Montevideo          11
#           Progreso            11
#           San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# ## Sorting

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#           country               province    len
# 179        Greece  Muscat of Kefallonian      1
# 192        Greece          Sterea Ellada      1
# 194        Greece                 Thraki      1
# 354  South Africa             Paardeberg      1
# 40         Brazil       Serra do Sudeste      1
# ..            ...                    ...    ...
# 409            US                 Oregon   5373
# 227         Italy                Tuscany   5897
# 118        France               Bordeaux   5941
# 415            US             Washington   8639
# 392            US             California  36247
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#           country         province    len
# 392            US       California  36247
# 415            US       Washington   8639
# 118        France         Bordeaux   5941
# 227         Italy          Tuscany   5897
# 409            US           Oregon   5373
# ..            ...              ...    ...
# 101       Croatia              Krk      1
# 247   New Zealand        Gladstone      1
# 357  South Africa  Piekenierskloof      1
# 63          Chile          Coelemu      1
# 149        Greece           Beotia      1
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# 2      Armenia           Armenia     2
# 6    Australia          Tasmania    42
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 420    Uruguay           Juanico    12
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %% [markdown]
# ## Dtypes

# %%
wine_reviews.price.dtype
# Out:
# dtype('float64')

# %%
wine_reviews.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# critic                    object
# dtype: object

# %%
wine_reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
# 3         87.0
# 4         87.0
#           ...
# 129966    90.0
# 129967    90.0
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
wine_reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Missing data

# %%
wine_reviews[pd.isnull(wine_reviews.country)]
# Out:
#         Unnamed: 0 country  ...                           winery    critic
# 913            913     NaN  ...               Gotsa Family Wines  everyone
# 3131          3131     NaN  ...                Barton & Guestier  everyone
# 4243          4243     NaN  ...  Kakhetia Traditional Winemaking  everyone
# 9509          9509     NaN  ...                         Tsililis  everyone
# 9750          9750     NaN  ...                         Ross-idi  everyone
# ...            ...     ...  ...                              ...       ...
# 124176      124176     NaN  ...                Les Frères Dutruy  everyone
# 129407      129407     NaN  ...                      El Capricho  everyone
# 129408      129408     NaN  ...                      El Capricho  everyone
# 129590      129590     NaN  ...                        Büyülübağ  everyone
# 129900      129900     NaN  ...                           Psagot  everyone
#
# [63 rows x 15 columns]

# %%
wine_reviews.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
#                 ...
# 129966              Unknown
# 129967         Oregon Other
# 129968              Unknown
# 129969              Unknown
# 129970              Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
wine_reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object
